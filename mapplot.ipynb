# %%
import json

# %%
india_states=json.load(open("states_india.geojson","r"))

# %%
india_states["features"][0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[78.34088, 19.883615],
#      [78.351327, 19.88184],
#      [78.370422, 19.883346],
#      [78.379149, 19.879733],
#      [78.388848, 19.879703],
#      [78.389673, 19.874372],
#      [78.388883, 19.864121],
#      [78.390691, 19.856213],
#      [78.390645, 19.853215],
#      [78.39395, 19.846705],
#      [78.402384, 19.836943],
#      [78.413779, 19.830435],
#      [78.433447, 19.8237],
#      [78.449385, 19.819844],
#      [78.469482, 19.816847],
#      [78.481036, 19.817011],
#      [78.489156, 19.807863],
#      [78.494337, 19.799196],
#      [78.498808, 19.793852],
#      [78.508559, 19.793125],
#      [78.514515, 19.801887],
#      [78.517292, 19.814976],
#      [78.52413, 19.820588],
#      [78.531195, 19.822351],
#      [78.562889, 19.81634],
#      [78.57869, 19.814543],
#      [78.590001, 19.81245],
#      [78.596781, 19.816171],
#      [78.600308, 19.818109],
#      [78.608696, 19.818273],
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("india_census.csv")

# %%
import pandas as pd

# %%
dfs=pd.read_html("https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population")

# %%
len(dfs)
# Out:
# 1

# %%
dfs[0]
# Out:
#    List of states and union territories of India by population (2011 Census of India)  \
#                                                                                  Rank
# 0                                              1 (S1)
# 1                                              2 (S2)
# 2                                              3 (S3)
# 3                                              4 (S4)
# 4                                              5 (S5)
# 5                                              6 (S6)
# 6                                              7 (S7)
# 7                                              8 (S8)
# 8                                              9 (S9)
# 9                                            10 (S10)
# 10                                           11 (S11)
# 11                                           12 (S12)
# 12                                           13 (S13)
# 13                                           14 (S14)
# ...

# %%
dfs[0].to_csv("india_census.csv")

# %%
df=pd.read_csv("india_census.csv")

# %%
df.head()
# Out:
#    Rank State or union territory  Population  Population (%)  \
# 0   1.0            Uttar Pradesh   199812341             NaN
# 1   2.0              Maharashtra   112374333             NaN
# 2   3.0                    Bihar   104099452             NaN
# 3   4.0              West Bengal    91276115             NaN
# 4   5.0           Madhya Pradesh    72626809             NaN
#
#   Decadal growth(2001–2011)  Rural population  Percent rural  \
# 0                    20.20%         155317278            NaN
# 1                    20.00%          61556074            NaN
# 2                    25.40%          92341436            NaN
# 3                    13.80%          62183113            NaN
# 4                    16.30%          52557404            NaN
#
#    Urban population  Percent urban                     Area[16]  \
# 0          44495063            NaN   240,928 km2 (93,023 sq mi)
# 1          50818259            NaN  307,713 km2 (118,809 sq mi)
# ...

# %%
df["Density[a]"].apply(lambda x:int(x.split("/")[0].replace(",","")))
# Out:
# 0       828
# 1       365
# 2      1102
# 3      1029
# 4       236
# 5       555
# 6       201
# 7       319
# 8       308
# 9       303
# 10      269
# 11      312
# 12      859
# 13      414
# 14      397
# 15      550
# 16      189
# 17      573
# 18      189
# 19      123
# 20      350
# 21      132
# 22      122
# 23      119
# 24      394
# 25       17
# 26       52
# 27       86
# 28    11297
# 29      297
# 30     2598
# 31     9252
# 32      970
# 33      970
# 34       46
# 35     2013
# Name: Density[a], dtype: int64

# %%
df["Density"]=df["Density[a]"].apply(lambda x:int(x.split("/")[0].replace(",","")))

# %%
state_id_map={}
for feature in india_states["features"]:
    feature["id"]=feature["properties"]["state_code"]
    state_id_map[feature["properties"]["st_nm"]]=feature["id"]

# %%
df["id"]=df["State or union territory"].apply(lambda x:state_id_map[x])

# %%
df.head()
# Out:
#    Rank State or union territory  Population  Population (%)  \
# 0   1.0            Uttar Pradesh   199812341             NaN
# 1   2.0              Maharashtra   112374333             NaN
# 2   3.0                    Bihar   104099452             NaN
# 3   4.0              West Bengal    91276115             NaN
# 4   5.0           Madhya Pradesh    72626809             NaN
#
#   Decadal growth(2001–2011)  Rural population  Percent rural  \
# 0                    20.20%         155317278            NaN
# 1                    20.00%          61556074            NaN
# 2                    25.40%          92341436            NaN
# 3                    13.80%          62183113            NaN
# 4                    16.30%          52557404            NaN
#
#    Urban population  Percent urban                     Area[16]  \
# 0          44495063            NaN   240,928 km2 (93,023 sq mi)
# 1          50818259            NaN  307,713 km2 (118,809 sq mi)
# ...

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "browser"

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
fig=px.choropleth(df,locations="id",geojson=india_states,color="Density", scope="asia", hover_name="State or union territory",hover_data=["Density"] )
fig.update_geos(fitbounds="locations",visible=False)

# %%
fig.show()

# %%
import numpy as np
df["DensityScale"]=np.log10(df["Density"])

# %%
import plotly.express as px
fig=px.choropleth(df,locations="id",geojson=india_states, color="DensityScale",hover_name="State or union territory",hover_data=["Density"])
fig.update_geos(fitbounds="locations",visible=False)
fig.show()

# %%
fig=px.choropleth_mapbox(df,locations="id",geojson=india_states,color="DensityScale",hover_name="State or union territory",hover_data=["Density"],mapbox_style="carto-positron",center={"lat":24,"lon":78},zoom=3,opacity=0.5)
fig.show()

# %%
df["SexRatioScale"]=df["Sex ratio"]-1000

# %%
fig=px.choropleth_mapbox(df,locations="id",geojson=india_states,color="SexRatioScale",hover_name="State or union territory",hover_data=["Sex ratio"],mapbox_style="carto-positron",center={"lat":24,"lon":78},zoom=3,opacity=0.5)
fig.show()
